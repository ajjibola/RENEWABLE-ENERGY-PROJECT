# %% [markdown]
# Project Content:
# Data Source: Our World in Data (https://ourworldindata.org/renewable-energy)
# Data Summary: I am interested in discovering the potentials of well known sources of renewable energy in meeting energy needs of households and industries.
# Description : I want to know :
#     Total energy produced through the respective sources of renewable energy technology under study.
#
#    Total energy produced through renewable energy technology in meeting the energy needs of household and industries.
#
#    Continents with distinguihed high or low energy generation through the sources of renewable energy technology under study.
#
#    Correlation of renewable energy potentials between continents.
#
#    Source of renewable energy potential of represented continents.
#
#    The contries or continents leading in renewable energy technology as far as the sources under study are concerned.
#
#
# Research Finding : Data for Traditional biofuel was estimated as total of world Traditional biofuel. Traditional biofuel has been in existence for a very long time which probably was the reason for insufficient data collection for the respective countries, continents and regions represented. Highest quantity of energy was derived from Traditional biofuel while .... produced lowest quantity of energy as at 2018.
# Further Research: I would be interested to see if there is significant correlation between bioenergy potential of identified sources and natural resource advantage of a countries, regions or continents of the world.

# %% [markdown]
#  Imports the useful tools.

# %%
 #Importing the useful tools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("renewable-energy-consumption 2.csv")

# %%
df
# Out:
#         Name      Code  Regions  population  Year  \
# 0     Africa       NaN      1.0         NaN  1965
# 1     Africa       NaN      1.0         NaN  1966
# 2     Africa       NaN      1.0         NaN  1967
# 3     Africa       NaN      1.0         NaN  1968
# 4     Africa       NaN      1.0         NaN  1969
# ...      ...       ...      ...         ...   ...
# 5103   World  OWID_WRL      NaN         NaN  2014
# 5104   World  OWID_WRL      NaN         NaN  2015
# 5105   World  OWID_WRL      NaN         NaN  2016
# 5106   World  OWID_WRL      NaN         NaN  2017
# 5107   World  OWID_WRL      NaN         NaN  2018
#
#       Traditional biofuels (terrawatt-hours)  Hydropower (terawatt-hours)  \
# 0                                        NaN                    14.278806
# 1                                        NaN                    15.649049
# 2                                        NaN                    16.158333
# ...

# %% [markdown]
# Renames the Columns of respective sources of Renewable Energy considered.

# %%
df2 = df.rename(columns={"Traditional biofuels (terrawatt-hours)": "T_biofuels", "Hydropower (terawatt-hours)": "Hydropower", "Solar (terawatt-hours)": "Solar", "Wind (terawatt-hours)":"Wind", "Other renewables (terawatt-hours)": "O_Renewables"})

# %%
df2
# Out:
#         Name      Code  Regions  population  Year   T_biofuels   Hydropower  \
# 0     Africa       NaN      1.0         NaN  1965          NaN    14.278806
# 1     Africa       NaN      1.0         NaN  1966          NaN    15.649049
# 2     Africa       NaN      1.0         NaN  1967          NaN    16.158333
# 3     Africa       NaN      1.0         NaN  1968          NaN    18.622983
# 4     Africa       NaN      1.0         NaN  1969          NaN    21.582897
# ...      ...       ...      ...         ...   ...          ...          ...
# 5103   World  OWID_WRL      NaN         NaN  2014  11220.06442  3883.143443
# 5104   World  OWID_WRL      NaN         NaN  2015  11111.11111  3884.417357
# 5105   World  OWID_WRL      NaN         NaN  2016  11003.21580  4017.743773
# 5106   World  OWID_WRL      NaN         NaN  2017  10895.32049  4065.443127
# 5107   World  OWID_WRL      NaN         NaN  2018          NaN  4193.104151
#
#            Solar         Wind  O_Renewables
# ...

# %% [markdown]
# Calculates the quantity of energy generated from respective sources of renewable energy.

# %%
T_biofuel_world = df2["T_biofuels"].sum()

# %%
T_biofuel_world
# Out:
# 693050.071051

# %%
df2[df2['T_biofuels']==df2['T_biofuels'].max()]
# Out:
#        Name      Code  Regions  population  Year  T_biofuels   Hydropower  \
# 5089  World  OWID_WRL      NaN         NaN  2000     12500.0  2654.703506
# 5090  World  OWID_WRL      NaN         NaN  2001     12500.0  2586.479369
#
#          Solar       Wind  O_Renewables
# 5089  1.125407  31.420937    185.452381
# 5090  1.409074  38.390947    191.228515

# %%
df2[df2['T_biofuels']==df2['T_biofuels'].min()]
# Out:
#        Name      Code  Regions  population  Year   T_biofuels  Hydropower  \
# 5037  World  OWID_WRL      NaN         NaN  1800  5555.555556         NaN
#
#       Solar  Wind  O_Renewables
# 5037    NaN   NaN           NaN

# %%
df2.sort_values('T_biofuels',  ascending=False).head()
# Out:
#        Name      Code  Regions  population  Year   T_biofuels   Hydropower  \
# 5090  World  OWID_WRL      NaN         NaN  2001  12500.00000  2586.479369
# 5089  World  OWID_WRL      NaN         NaN  2000  12500.00000  2654.703506
# 5091  World  OWID_WRL      NaN         NaN  2002  12470.00000  2633.589747
# 5088  World  OWID_WRL      NaN         NaN  1999  12414.05573  2608.299500
# 5092  World  OWID_WRL      NaN         NaN  2003  12328.70237  2628.619237
#
#          Solar       Wind  O_Renewables
# 5090  1.409074  38.390947    191.228515
# 5089  1.125407  31.420937    185.452381
# 5091  1.775371  52.331757    205.853182
# 5088  0.916197  21.216174    177.198316
# 5092  2.269183  62.916927    217.379149

# %%
df2.sort_values('T_biofuels',  ascending=False).tail()
# Out:
#                 Name      Code  Regions  population  Year  T_biofuels  \
# 5033  Western Africa       NaN      1.0         NaN  2015         NaN
# 5034  Western Africa       NaN      1.0         NaN  2016         NaN
# 5035  Western Africa       NaN      1.0         NaN  2017         NaN
# 5036  Western Africa       NaN      1.0         NaN  2018         NaN
# 5107           World  OWID_WRL      NaN         NaN  2018         NaN
#
#        Hydropower       Solar         Wind  O_Renewables
# 5033    15.468794    0.125173     0.179616      0.236833
# 5034    15.746255    0.221656     0.177467      0.294992
# 5035    18.556151    0.341484     0.176432      0.294186
# 5036    19.375439    0.523855     0.176432      0.294186
# 5107  4193.104151  584.630918  1269.953375    625.805362

# %%
import seaborn as sns
import numpy as np
sns.distplot(df2["T_biofuels"], bins= 1)

# %% [markdown]
# Changes index.

# %%
df2.set_index('Name', inplace=True)

# %%
df2
# Out:
#             Code  Regions  population  Year   T_biofuels   Hydropower  \
# Name
# Africa       NaN      1.0         NaN  1965          NaN    14.278806
# Africa       NaN      1.0         NaN  1966          NaN    15.649049
# Africa       NaN      1.0         NaN  1967          NaN    16.158333
# Africa       NaN      1.0         NaN  1968          NaN    18.622983
# Africa       NaN      1.0         NaN  1969          NaN    21.582897
# ...          ...      ...         ...   ...          ...          ...
# World   OWID_WRL      NaN         NaN  2014  11220.06442  3883.143443
# World   OWID_WRL      NaN         NaN  2015  11111.11111  3884.417357
# World   OWID_WRL      NaN         NaN  2016  11003.21580  4017.743773
# World   OWID_WRL      NaN         NaN  2017  10895.32049  4065.443127
# World   OWID_WRL      NaN         NaN  2018          NaN  4193.104151
#
#              Solar         Wind  O_Renewables
# Name
# Africa    0.000000     0.000000      0.000000
# ...

# %% [markdown]
# Drops world as an index.

# %%
df3 = df2.drop(['World'])

# %%
df3
# Out:
#                Code  Regions  population  Year  T_biofuels  Hydropower  \
# Name
# Africa          NaN      1.0         NaN  1965         NaN   14.278806
# Africa          NaN      1.0         NaN  1966         NaN   15.649049
# Africa          NaN      1.0         NaN  1967         NaN   16.158333
# Africa          NaN      1.0         NaN  1968         NaN   18.622983
# Africa          NaN      1.0         NaN  1969         NaN   21.582897
# ...             ...      ...         ...   ...         ...         ...
# Western Africa  NaN      1.0         NaN  2014         NaN   17.754943
# Western Africa  NaN      1.0         NaN  2015         NaN   15.468794
# Western Africa  NaN      1.0         NaN  2016         NaN   15.746255
# Western Africa  NaN      1.0         NaN  2017         NaN   18.556151
# Western Africa  NaN      1.0         NaN  2018         NaN   19.375439
#
#                    Solar      Wind  O_Renewables
# Name
# Africa          0.000000  0.000000      0.000000
# ...

# %%
df3.head()
# Out:
#        Code  Regions  population  Year  T_biofuels  Hydropower  Solar  Wind  \
# Name
# Africa  NaN      1.0         NaN  1965         NaN   14.278806    0.0   0.0
# Africa  NaN      1.0         NaN  1966         NaN   15.649049    0.0   0.0
# Africa  NaN      1.0         NaN  1967         NaN   16.158333    0.0   0.0
# Africa  NaN      1.0         NaN  1968         NaN   18.622983    0.0   0.0
# Africa  NaN      1.0         NaN  1969         NaN   21.582897    0.0   0.0
#
#         O_Renewables
# Name
# Africa           0.0
# Africa           0.0
# Africa           0.0
# Africa           0.0
# Africa           0.0

# %%
df3.tail()
# Out:
#                Code  Regions  population  Year  T_biofuels  Hydropower  \
# Name
# Western Africa  NaN      1.0         NaN  2014         NaN   17.754943
# Western Africa  NaN      1.0         NaN  2015         NaN   15.468794
# Western Africa  NaN      1.0         NaN  2016         NaN   15.746255
# Western Africa  NaN      1.0         NaN  2017         NaN   18.556151
# Western Africa  NaN      1.0         NaN  2018         NaN   19.375439
#
#                    Solar      Wind  O_Renewables
# Name
# Western Africa  0.111813  0.091841      0.196826
# Western Africa  0.125173  0.179616      0.236833
# Western Africa  0.221656  0.177467      0.294992
# Western Africa  0.341484  0.176432      0.294186
# Western Africa  0.523855  0.176432      0.294186

# %%
df3.describe()
# Out:
#        Regions  population         Year  T_biofuels   Hydropower        Solar  \
# count   1006.0         0.0  5037.000000         0.0  5037.000000  5037.000000
# mean       1.0         NaN  1992.323407         NaN    49.901758     0.885941
# std        0.0         NaN    15.464904         NaN   134.525746     8.881940
# min        1.0         NaN  1965.000000         NaN     0.000000     0.000000
# 25%        1.0         NaN  1979.000000         NaN     0.799911     0.000000
# 50%        1.0         NaN  1993.000000         NaN     5.851000     0.000000
# 75%        1.0         NaN  2006.000000         NaN    28.435330     0.002000
# max        1.0         NaN  2018.000000         NaN  1718.508325   314.208553
#
#               Wind  O_Renewables
# count  5037.000000   4983.000000
# mean      3.222344      3.873301
# std      23.305398     15.164595
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.036033
# ...

# %%
Calculates the quantity of energy generated from respective sources of renewable energy and the total energy generated.

# %%
T_biofuel_total = df3["T_biofuels"].sum()

# %%
T_biofuel_total
# Out:
# 0.0

# %%
Total_Hydropower = df2["Hydropower"].sum()

# %%
Total_Hydropower
# Out:
# 377032.729306407

# %%
Total_Solar = df2["Solar"].sum()

# %%
Total_Solar
# Out:
# 6693.727280854499

# %%
Total_Wind = df2["Wind"].sum()

# %%
Total_Wind
# Out:
# 24346.417013975002

# %%
Total_OtherSources = df2["O_Renewables"].sum()

# %%
Total_OtherSources
# Out:
# 28950.989364176

# %%
Tota_Energy = T_biofuel_world + Total_Hydropower + Total_Solar + Total_Wind + Total_OtherSources
Tota_Energy
# Out:
# 1130073.9340164126

# %%
Shows the continent(s) with highest and lowest value of energy with respect to each sources of renewable energy considered.

# %%
df3[df3['T_biofuels']==df3['T_biofuels'].max()]
# Out:
# Empty DataFrame
# Columns: [Code, Regions, population, Year, T_biofuels, Hydropower, Solar, Wind, O_Renewables]
# Index: []

# %%
df3[df3['T_biofuels']==df3['T_biofuels'].min()]
# Out:
# Empty DataFrame
# Columns: [Code, Regions, population, Year, T_biofuels, Hydropower, Solar, Wind, O_Renewables]
# Index: []

# %%
df3[df3['Hydropower']==df3['Hydropower'].max()]
# Out:
#              Code  Regions  population  Year  T_biofuels   Hydropower  \
# Name
# Asia Pacific  NaN      1.0         NaN  2018         NaN  1718.508325
#
#                    Solar        Wind  O_Renewables
# Name
# Asia Pacific  314.208553  460.469456    221.301517

# %%
df3[df3['Hydropower']==df3['Hydropower'].min()]
# Out:
#                      Code  Regions  population  Year  T_biofuels  Hydropower  \
# Name
# Bangladesh            BGD      NaN         NaN  1965         NaN         0.0
# Bangladesh            BGD      NaN         NaN  1966         NaN         0.0
# Bangladesh            BGD      NaN         NaN  1967         NaN         0.0
# Bangladesh            BGD      NaN         NaN  1968         NaN         0.0
# Bangladesh            BGD      NaN         NaN  1969         NaN         0.0
# ...                   ...      ...         ...   ...         ...         ...
# United Arab Emirates  ARE      NaN         NaN  2014         NaN         0.0
# United Arab Emirates  ARE      NaN         NaN  2015         NaN         0.0
# United Arab Emirates  ARE      NaN         NaN  2016         NaN         0.0
# United Arab Emirates  ARE      NaN         NaN  2017         NaN         0.0
# United Arab Emirates  ARE      NaN         NaN  2018         NaN         0.0
#
# ...

# %%
sns.distplot(df2["Hydropower"], bins= 1)

# %%
df3[df3['Solar']==df3['Solar'].max()]
# Out:
#              Code  Regions  population  Year  T_biofuels   Hydropower  \
# Name
# Asia Pacific  NaN      1.0         NaN  2018         NaN  1718.508325
#
#                    Solar        Wind  O_Renewables
# Name
# Asia Pacific  314.208553  460.469456    221.301517

# %%
df3[df3['Solar']==df3['Solar'].min()]
# Out:
#                Code  Regions  population  Year  T_biofuels  Hydropower  Solar  \
# Name
# Africa          NaN      1.0         NaN  1965         NaN   14.278806    0.0
# Africa          NaN      1.0         NaN  1966         NaN   15.649049    0.0
# Africa          NaN      1.0         NaN  1967         NaN   16.158333    0.0
# Africa          NaN      1.0         NaN  1968         NaN   18.622983    0.0
# Africa          NaN      1.0         NaN  1969         NaN   21.582897    0.0
# ...             ...      ...         ...   ...         ...         ...    ...
# Western Africa  NaN      1.0         NaN  1995         NaN   14.167979    0.0
# Western Africa  NaN      1.0         NaN  1996         NaN   14.687782    0.0
# Western Africa  NaN      1.0         NaN  1997         NaN   15.026480    0.0
# Western Africa  NaN      1.0         NaN  1998         NaN   11.908342    0.0
# Western Africa  NaN      1.0         NaN  1999         NaN   13.960687    0.0
#
# ...

# %%
sns.distplot(df2["Solar"], bins= 1)

# %%
df3[df3['Wind']==df3['Wind'].max()]
# Out:
#              Code  Regions  population  Year  T_biofuels   Hydropower  \
# Name
# Asia Pacific  NaN      1.0         NaN  2018         NaN  1718.508325
#
#                    Solar        Wind  O_Renewables
# Name
# Asia Pacific  314.208553  460.469456    221.301517

# %%
df3[df3['Wind']==df3['Wind'].min()]
# Out:
#                Code  Regions  population  Year  T_biofuels  Hydropower  Solar  \
# Name
# Africa          NaN      1.0         NaN  1965         NaN   14.278806    0.0
# Africa          NaN      1.0         NaN  1966         NaN   15.649049    0.0
# Africa          NaN      1.0         NaN  1967         NaN   16.158333    0.0
# Africa          NaN      1.0         NaN  1968         NaN   18.622983    0.0
# Africa          NaN      1.0         NaN  1969         NaN   21.582897    0.0
# ...             ...      ...         ...   ...         ...         ...    ...
# Western Africa  NaN      1.0         NaN  1988         NaN   10.821000    0.0
# Western Africa  NaN      1.0         NaN  1989         NaN   11.741000    0.0
# Western Africa  NaN      1.0         NaN  1990         NaN   11.917091    0.0
# Western Africa  NaN      1.0         NaN  1991         NaN   13.887131    0.0
# Western Africa  NaN      1.0         NaN  1992         NaN   14.273202    0.0
#
# ...

# %%
sns.distplot(df2["Wind"], bins= 1)

# %%
df3[df3['O_Renewables']==df3['O_Renewables'].max()]
# Out:
#              Code  Regions  population  Year  T_biofuels   Hydropower  \
# Name
# Asia Pacific  NaN      1.0         NaN  2018         NaN  1718.508325
#
#                    Solar        Wind  O_Renewables
# Name
# Asia Pacific  314.208553  460.469456    221.301517

# %%
df3[df3['O_Renewables']==df3['O_Renewables'].min()]
# Out:
#                Code  Regions  population  Year  T_biofuels  Hydropower  Solar  \
# Name
# Africa          NaN      1.0         NaN  1965         NaN   14.278806    0.0
# Africa          NaN      1.0         NaN  1966         NaN   15.649049    0.0
# Africa          NaN      1.0         NaN  1967         NaN   16.158333    0.0
# Africa          NaN      1.0         NaN  1968         NaN   18.622983    0.0
# Africa          NaN      1.0         NaN  1969         NaN   21.582897    0.0
# ...             ...      ...         ...   ...         ...         ...    ...
# Western Africa  NaN      1.0         NaN  1966         NaN    1.522550    0.0
# Western Africa  NaN      1.0         NaN  1967         NaN    1.703706    0.0
# Western Africa  NaN      1.0         NaN  1968         NaN    2.045157    0.0
# Western Africa  NaN      1.0         NaN  1969         NaN    2.843553    0.0
# Western Africa  NaN      1.0         NaN  1970         NaN    3.440998    0.0
#
# ...

# %%
sns.distplot(df2["O_Renewables"], bins= 1)

# %%
sns.barplot(x=df3['Solar'].head(100), y=df3['Wind'].head(100))
plt.title('Solar and Wind Comparison')
plt.rc('figure', figsize=(40, 10))

# %%
sns.barplot(x=df3['Hydropower'].head(20), y=df3['O_Renewables'].head(20))
plt.title('Solar and Wind Comparison')
plt.rc('figure', figsize=(40, 10))

# %%
Groups the countries into continents.

# %%
Country_group = df3.groupby('Name')
Country_group

# %%
Country_group.get_group('Africa').max()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            2018.000000
# T_biofuels              NaN
# Hydropower       132.840769
# Solar              9.029089
# Wind              14.685940
# O_Renewables       8.161023
# dtype: float64

# %%
height = [132.840769, 9.029089, 14.685940, 8.161023]
bars = ('Hydropower', 'Solar', 'Wind', 'O_Renewables')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
#include title
plt.suptitle('Africa Energy Potentials')
 
 
# Show graphic
plt.show()

# %%
Country_group.get_group('Africa').min()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            1965.000000
# T_biofuels              NaN
# Hydropower        14.278806
# Solar              0.000000
# Wind               0.000000
# O_Renewables       0.000000
# dtype: float64

# %%
Country_group.get_group('Europe').max()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            2018.000000
# T_biofuels              NaN
# Hydropower       661.562560
# Solar            139.052063
# Wind             404.369480
# O_Renewables     217.632497
# dtype: float64

# %%
height = [661.562560, 139.052063, 404.369480, 217.632497]
bars = ('Hydropower', 'Solar', 'Wind', 'O_Renewables')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
#include title
plt.suptitle('Europe Energy Potentials')
 
# Show graphic
plt.show()

# %%
Country_group.get_group('Europe').min()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            1965.000000
# T_biofuels              NaN
# Hydropower       302.516086
# Solar              0.000000
# Wind               0.000000
# O_Renewables       3.009000
# dtype: float64

# %%
Country_group.get_group('Australia').max()
# Out:
# Code                AUS
# Regions            None
# population         None
# Year               2018
# T_biofuels         None
# Hydropower       19.634
# Solar           12.0811
# Wind            16.2665
# O_Renewables      4.275
# dtype: object

# %%
height = [19.634, 12.0811, 16.2665, 4.275]
bars = ('Hydropower', 'Solar', 'Wind', 'O_Renewables')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
#include title
plt.suptitle('Australia Energy Potentials')
 
# Show graphic
plt.show()

# %%
Country_group.get_group('Australia').min()
# Out:
# Code                AUS
# Regions            None
# population         None
# Year               1965
# T_biofuels         None
# Hydropower      7.34504
# Solar                 0
# Wind                  0
# O_Renewables      0.261
# dtype: object

# %%
Country_group.get_group('North America').max()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            2018.000000
# T_biofuels              NaN
# Hydropower       733.477832
# Solar            102.907233
# Wind             322.528364
# O_Renewables     100.353372
# dtype: float64

# %%
height = [733.477832, 102.907233, 322.528364, 100.353372]
bars = ('Hydropower', 'Solar', 'Wind', 'O_Renewables')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
#include title
plt.suptitle('North America Energy Potentials')
 
# Show graphic
plt.show()

# %%
Country_group.get_group('North America').min()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            1965.000000
# T_biofuels              NaN
# Hydropower       324.957922
# Solar              0.000000
# Wind               0.000000
# O_Renewables      13.332232
# dtype: float64

# %%
Country_group.get_group('Asia Pacific').max()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            2018.000000
# T_biofuels              NaN
# Hydropower      1718.508325
# Solar            314.208553
# Wind             460.469456
# O_Renewables     221.301517
# dtype: float64

# %%
height = [1718.508325, 314.208553, 460.469456, 221.301517]
bars = ('Hydropower', 'Solar', 'Wind', 'O_Renewables')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
#include title
plt.suptitle('Asia Pacific Energy Potentials')
 
# Show graphic
plt.show()

# %% [markdown]
# Evaluating the correlation of renewable energy potentials between continents.

# %%
correlation = {'Africa': [132.840769,9.029089,14.685940,8.161023],
        'Europe': [661.562560,139.052063,404.369480,217.632497],
        'Australia': [19.634,12.0811,16.2665,4.275],
               'North America': [733.477832,102.907233,322.528364,100.353372],
               'Asia Pacific': [1718.508325,314.208553,460.469456,221.301517]
        }

df = pd.DataFrame(correlation,columns=['Africa','Europe','Australia','North America', 'Asia Pacific'])
print (df)
# Out:
#        Africa      Europe  Australia  North America  Asia Pacific
# 0  132.840769  661.562560    19.6340     733.477832   1718.508325
# 1    9.029089  139.052063    12.0811     102.907233    314.208553
# 2   14.685940  404.369480    16.2665     322.528364    460.469456
# 3    8.161023  217.632497     4.2750     100.353372    221.301517

# %%
corrMatrix = df.corr()
print (corrMatrix)
# Out:
#                  Africa    Europe  Australia  North America  Asia Pacific
# Africa         1.000000  0.897575   0.690277       0.952288      0.995363
# Europe         0.897575  1.000000   0.777999       0.982282      0.921136
# Australia      0.690277  0.777999   1.000000       0.822391      0.755388
# North America  0.952288  0.982282   0.822391       1.000000      0.973145
# Asia Pacific   0.995363  0.921136   0.755388       0.973145      1.000000

# %%
import seaborn as sn
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
Country_group.get_group('Asia Pacific').min()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            1965.000000
# T_biofuels              NaN
# Hydropower       150.557596
# Solar              0.000000
# Wind               0.000000
# O_Renewables       1.424000
# dtype: float64

# %%
Country_group.get_group('Other Northern Africa').max()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            2018.000000
# T_biofuels              NaN
# Hydropower         0.291680
# Solar              0.111624
# Wind               0.507000
# O_Renewables            NaN
# dtype: float64

# %%
Country_group.get_group('Other Northern Africa').min()
# Out:
# Code                  NaN
# Regions            1.0000
# population            NaN
# Year            1965.0000
# T_biofuels            NaN
# Hydropower         0.0165
# Solar              0.0000
# Wind               0.0000
# O_Renewables          NaN
# dtype: float64

# %%
Country_group.get_group('Other Southern Africa').max()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            2018.000000
# T_biofuels              NaN
# Hydropower         2.364700
# Solar              0.128029
# Wind               0.000000
# O_Renewables       0.284700
# dtype: float64

# %%
Country_group.get_group('Other Southern Africa').min()
# Out:
# Code                    NaN
# Regions            1.000000
# population              NaN
# Year            1965.000000
# T_biofuels              NaN
# Hydropower         0.352455
# Solar              0.000000
# Wind               0.000000
# O_Renewables       0.000000
# dtype: float64

# %%
Country_group.get_group('South Africa').max()
# Out:
# Code                 ZAF
# Regions             None
# population          None
# Year                2018
# T_biofuels          None
# Hydropower         3.162
# Solar            4.93523
# Wind             6.89477
# O_Renewables    0.530431
# dtype: object

# %%
Country_group.get_group('Egypt').max()
# Out:
# Code                EGY
# Regions            None
# population         None
# Year               2018
# T_biofuels         None
# Hydropower       15.096
# Solar           1.03574
# Wind             2.5258
# O_Renewables          0
# dtype: object

# %%
Country_group.get_group('United States').max()
# Out:
# Code                USA
# Regions            None
# population         None
# Year               2018
# T_biofuels         None
# Hydropower      355.973
# Solar           97.1182
# Wind            277.729
# O_Renewables    84.0702
# dtype: object

# %%
Country_group.get_group('Canada').max()
# Out:
# Code                CAN
# Regions            None
# population         None
# Year               2018
# T_biofuels         None
# Hydropower      396.502
# Solar           3.54625
# Wind            32.1701
# O_Renewables     11.035
# dtype: object

# %%
Country_group.get_group('Germany').max()
# Out:
# Code                DEU
# Regions            None
# population         None
# Year               2018
# T_biofuels         None
# Hydropower      24.8667
# Solar            46.164
# Wind             111.59
# O_Renewables     51.437
# dtype: object

# %%
Country_group.get_group('China').max()
# Out:
# Code                CHN
# Regions            None
# population         None
# Year               2018
# T_biofuels         None
# Hydropower      1202.43
# Solar             177.5
# Wind                366
# O_Renewables    90.7235
# dtype: object

# %%
df3.sort_values('Hydropower', ascending=False).head().plot.hist();
plt.title("Hydropower");

# %%
df3.sort_values('Hydropower', ascending=False).tail()
# Out:
#           Code  Regions  population  Year  T_biofuels  Hydropower   Solar  \
# Name
# Ukraine    UKR      NaN         NaN  1972         NaN         0.0  0.0000
# Ukraine    UKR      NaN         NaN  1973         NaN         0.0  0.0000
# Ukraine    UKR      NaN         NaN  1974         NaN         0.0  0.0000
# Ukraine    UKR      NaN         NaN  1975         NaN         0.0  0.0000
# Singapore  SGP      NaN         NaN  2015         NaN         0.0  0.0723
#
#            Wind  O_Renewables
# Name
# Ukraine     0.0         0.000
# Ukraine     0.0         0.000
# Ukraine     0.0         0.000
# Ukraine     0.0         0.000
# Singapore   0.0         0.854

# %%
checks the continents leading in respective source of renewable energy considered.

# %%
df3.sort_values('Solar', ascending=False).head(20).plot.hist();
plt.title("Solar");

# %%
df3.sort_values('Solar', ascending=False).tail()
# Out:
#         Code  Regions  population  Year  T_biofuels  Hydropower  Solar  Wind  \
# Name
# Morocco  MAR      NaN         NaN  1995         NaN    0.611000    0.0   0.0
# Morocco  MAR      NaN         NaN  1996         NaN    1.957000    0.0   0.0
# Morocco  MAR      NaN         NaN  1997         NaN    2.083000    0.0   0.0
# Morocco  MAR      NaN         NaN  1998         NaN    1.777000    0.0   0.0
# Africa   NaN      1.0         NaN  1965         NaN   14.278806    0.0   0.0
#
#          O_Renewables
# Name
# Morocco           0.0
# Morocco           0.0
# Morocco           0.0
# Morocco           0.0
# Africa            0.0

# %%
df3.sort_values('Wind',  ascending=False).head().plot.hist();
plt.title("Wind");

# %%
df3.sort_values('Wind',  ascending=False).tail()
# Out:
#          Code  Regions  population  Year  T_biofuels  Hydropower    Solar  \
# Name
# Italy     ITA      NaN         NaN  1968         NaN      42.677  0.00000
# Italy     ITA      NaN         NaN  1969         NaN      41.166  0.00000
# Italy     ITA      NaN         NaN  1970         NaN      40.373  0.00000
# Italy     ITA      NaN         NaN  1971         NaN      39.079  0.00000
# Malaysia  MYS      NaN         NaN  2007         NaN       5.957  0.00001
#
#           Wind  O_Renewables
# Name
# Italy      0.0         3.617
# Italy      0.0         3.812
# Italy      0.0         4.228
# Italy      0.0         4.209
# Malaysia   0.0         0.000

# %%
df3.sort_values('O_Renewables',  ascending=False).head(20).plot.hist();
plt.title("O_Renewables");

# %%
df3.sort_values('O_Renewables',  ascending=False).tail()
# Out:
#                       Code  Regions  population  Year  T_biofuels  Hydropower  \
# Name
# Other Northern Africa  NaN      1.0         NaN  2014         NaN     0.05600
# Other Northern Africa  NaN      1.0         NaN  2015         NaN     0.06900
# Other Northern Africa  NaN      1.0         NaN  2016         NaN     0.04466
# Other Northern Africa  NaN      1.0         NaN  2017         NaN     0.01746
# Other Northern Africa  NaN      1.0         NaN  2018         NaN     0.01650
#
#                           Solar     Wind  O_Renewables
# Name
# Other Northern Africa  0.032144  0.50700           NaN
# Other Northern Africa  0.046944  0.44900           NaN
# Other Northern Africa  0.078245  0.47434           NaN
# Other Northern Africa  0.100492  0.44861           NaN
# Other Northern Africa  0.111624  0.45300           NaN
